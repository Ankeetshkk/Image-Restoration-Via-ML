# %%
from skimage import io
from skimage.restoration import denoise_bilateral
from skimage import segmentation
from skimage.util import random_noise

# %%
img = io.imread("../standard_test_images/barbara.tif")

# %% [markdown]
# rom skimage.morphology import watershed
# segmentation = watershed(elevation_map, markers)

# %%
img=random_noise(img,mode="gaussian")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-36-936cd7310911> in <module>()
# ----> 1 img=random_noise(img,mode="gaussian")
#
# NameError: name 'random_noise' is not defined

# %%
io.imshow(img)
io.show()
io.imshow(denoise_bilateral(img,sigma_color=0.05,sigma_spatial=15,multichannel=False))
io.show()
